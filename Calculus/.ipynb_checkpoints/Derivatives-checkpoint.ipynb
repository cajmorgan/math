# %% [markdown]
# # Derivatives
# ## The fundamental concept and question of Calculus, what is the velocity at a specific point in time?
# ### i.e how much does a function increase/decrease at a specific point $x$?
#
# ### Tangent
# A tangent line is basically the line touching a curve that just intersects at one specific point. This line can be found by taking two points on the graph and slide them closer and closer together untill they are so close they would resemble on point. #SHOW VISUALS BETTER EXP
#
# #### Finding the slope of two points
#
# #### Using a limit on the function SHOW how x^2 goes to 2x .... with + h
#
# #### Finding the equation of a tangent line touching the graph at point $x$
# Let's say we have the function $f(x) = x^2$ and we want to find the line $g(x) = mx + b$ at point $x$ which is tangent to the funciton. We know this line touches the function $f(x)$ by definition and that it's slope $m = 2x$ (by checking the above proof of x^2). This means that at some point $f(x) = g(x)$. We already know how to find m at any point, but what about b?
#
# **Find tangent equation formula**
# ### $g(x) = f'(x)x_1 + (f(x) - f'(x)x)$
#
# <br>
# <br>
# $m = f'(x)$
#
# $m = 2x$
#
# $f(x) = g(x)$
#
# $f(x) = f'(x)x + b$
#
# $f(x) - f'(x)x = b$
#
# $g(x) = f'(x)x_1 + (f(x) - f'(x)x)$ // **This is the generalized form of the formula**
#
# $g(x) = mx_1 + (f(x) - mx)$ // With m
#
# $g(x) = 2xx_1 + (x^2 - (2x^2)$ // Substituting the function $f(x) = x^2$ and it's derivative $m = 2x$
#
# $g(x) = 2xx_1 - x^2$ // Notice the subtraction, this will look different depending on the function and cancels nicely in this case with $x^2$
#
# <br>
# <br>
# Notice that we have $x_1$ and not $x$ and that's because we want to keep that x in the equation for our answer and not replace it with the input of $x$ where we choose where the tangent will intersect the curve.
#
# We want to find the equation for the line where $x = 5.4$
#
# $g(5.4) = 2(5.4)x_1 - 5.4^2$
#
# $g(5.4) = 10.8x_1 - 29.16$
#
# The equation for the tangent line at 5.4 for function $f(x)$ is:
#
# $y = 10.8x_1 - 29.16$
#
# $x = 3$
#
# $g(3) = 2(3)x_1 - 3^2$
# $g(3) = 6x_1 - 9$
#
# $y = 6x_1 - 9$
#
#
# ### Rules of Derivatives
# Fortunately we don't have to derive every derivative of every function in which a long formula, as there are some very handy rules for many different type of functions that are always applicable for those.
#
# ### - Power Rule $\frac{d}{dx}x^n = nx^{n-1} $
#
# ### - Chain Rule $y(g), g(x), y(x)?$ $\frac{d}{dx}y(g(x)) = \frac{dy}{dg}\frac{dg}{dx}$
#
# ### - Exponential Rule $\frac{d}{dx} e^{kx} = ke^{kx} \to \frac{d}{dx} a^{kx} = ln(a)ka^{kx}$
#
# #### Power Rule
#
#
# #### Chain Rule
# When using the chain rule, as an example it's good to consider a function that gets an effect from another function, just like a chain of events. F.e let's say we have the function $V(r)$ that depends on the variable $r$, the radius. Let's say that $r$ depends on time in seconds $r(t)$. The most important thing here to understand is that the variable or function $r$ is dependent or independent completely depending on **context**.
#
# What would the derivative of $V(r)$ be? Well, it will just be $\frac{dV}{dr}$, simple as usual, but what would the derivative of $V(t) = V(r(t))$ be? $V(t)$ first depends on $r$ which depends on $t$, this means that we can't use derive it as usual, here we need the chain rule, which states:
#
# $\frac{dV}{dt} = \frac{dV}{dr} \times \frac{dr}{dt}$
#
# The nice thing about the chain rule is that the ratio (which some say you shouldn't treat as a ratio) cancels out nicely.
#
# #### Product Rule
#
#
#
#
# ### Deriving derivatives of different functions (proofs)
#
#
#
# ## Implicit and Explicit Derivatives
#
# ### Implicit Derivative
# When deriving implicitly, f.e $y^2 = x^2 + 1$ we can derive this with respect to $x$, but as we know $y$ is a function of the input $x$ we need to use the **Chain Rule** everytime we take the derivative of $y$ with respect to $x$. **"Respect to x"** simply means that we are applying the change to $x$ f.e $\frac{f(x + h) - f(x)}{h}$ where h is the change and therefore $y$ is the resulting effect of applying that change to $x$. This is the reason in implicit derivatives, we can derive $x$ explicitly but not $y$.
#
# In the following example, $y^2$ is actually a set of two functions $f(g(x))$ as y itself is a function of x and then we have the outer function exponent $f(y) = y^2$ which means what we are really taking the derivative of on the left side is both the inner function of $y = g(x)$ and the outer $f(y) = y^2$. Easy example:
#
# $y^2 = x^2 + 1$
#
# $2y\frac{dy}{dx} = \frac{d}{dx}(x^2) $ *Chain Rule on the left side*
#
# $2yy^\prime = 2x$
#
# $y^\prime = \frac{x}{y}$
#
# This basically creates a differential equation, but we already know $y$ therefore:
#
# $y = \sqrt{x^2 + 1}$
#
# $y^\prime = \frac{x}{\sqrt{x^2 + 1}}$
#
# And as an exercise, take the derivative of $y$ directly after taking the square root of both sides and you will end up with the same answer.
